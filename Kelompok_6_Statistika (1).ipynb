# %%
# Import semua library yang dibutuhkan
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import statsmodels.api as sm

print("Library berhasil diimport!")
# Out:
# Library berhasil diimport!

# %%
# Load dataset
df = pd.read_csv('study_performance.csv')

# Filter hanya Group C
groupC = df[df['race_ethnicity'] == 'group C']['math_score'].reset_index(drop=True)

# Random sampling 100 data
# random_state=42 artinya hasil sampelnya SELALU SAMA setiap dijalankan
np.random.seed(42)
sample = groupC.sample(n=100, random_state=42).reset_index(drop=True)

print(f"Total data Group C   : {len(groupC)}")
print(f"Jumlah sampel        : {len(sample)}")
print(f"\nData sampel:")
print(sample.values)
# Out:
# Total data Group C   : 319
# Jumlah sampel        : 100
#
# Data sampel:
# [85 63 65 35 70 82 68 32 35 52 53 64 81 56 75 83 79 74 91 87 40 47 92 58
#  22 69 57 84 59 72 85 46 79 73 67 65 62 44 68 86 69 64 70 71 96 69 61 81
#  29 69 77 73 54 52  0 79 71 67 76 66 58 61 68 57 44 78 59 65 78 67 40 64
#  75 67 58 77 70 67 58 67 91 59 46 54 54 98 49 66 65 61 58 68 67 58 48 86
#  75 58 65 63]

# %%
# Statistik Deskriptif
mean   = sample.mean()
median = sample.median()
std    = sample.std(ddof=1)
var    = sample.var(ddof=1)
min_   = sample.min()
max_   = sample.max()
q1     = sample.quantile(0.25)
q3     = sample.quantile(0.75)
iqr    = q3 - q1
skew   = sample.skew()
kurt   = sample.kurt()
cv     = (std / mean) * 100

print("=" * 40)
print("     STATISTIKA DESKRIPTIF")
print("=" * 40)
print(f"Jumlah Data (n)    : {len(sample)}")
print(f"Rata-rata          : {mean:.4f}")
print(f"Median             : {median:.4f}")
print(f"Standar Deviasi    : {std:.4f}")
print(f"Variansi           : {var:.4f}")
print(f"Nilai Minimum      : {min_}")
print(f"Nilai Maksimum     : {max_}")
print(f"Range              : {max_ - min_}")
print(f"Q1                 : {q1}")
print(f"Q3                 : {q3}")
print(f"IQR                : {iqr}")
print(f"Skewness           : {skew:.4f}")
print(f"Kurtosis           : {kurt:.4f}")
print(f"Koefisien Variasi  : {cv:.2f}%")
print("=" * 40)
# Out:
# ========================================
#      STATISTIKA DESKRIPTIF
# ========================================
# Jumlah Data (n)    : 100
# Rata-rata          : 64.6600
# Median             : 66.5000
# Standar Deviasi    : 16.0480
# Variansi           : 257.5398
# Nilai Minimum      : 0
# Nilai Maksimum     : 98
# Range              : 98
# Q1                 : 58.0
# Q3                 : 75.0
# IQR                : 17.0
# Skewness           : -0.8552
# Kurtosis           : 2.1403
# Koefisien Variasi  : 24.82%
# ========================================

# %%
# ==============================
# VISUALISASI 1 — HISTOGRAM
# ==============================

plt.figure(figsize=(10, 6))

# Plot histogram
sns.histplot(sample, bins=15, kde=True,
             color='steelblue', edgecolor='white',
             kde_kws={'color': 'darkblue', 'linewidth': 2})

# Garis rata-rata
plt.axvline(mean, color='red', linestyle='--',
            linewidth=2, label=f'Mean = {mean:.2f}')

# Garis median
plt.axvline(median, color='green', linestyle='-.',
            linewidth=2, label=f'Median = {median:.2f}')

# Label dan judul
plt.title('Histogram Nilai Matematika Siswa Kelompok Etnis C',
          fontsize=14, fontweight='bold', pad=15)
plt.xlabel('Nilai Matematika', fontsize=12)
plt.ylabel('Frekuensi', fontsize=12)
plt.legend(fontsize=11)
plt.tight_layout()
plt.savefig('histogram.png', dpi=150, bbox_inches='tight')
plt.show()
print("Histogram berhasil disimpan!")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_459/4167432887.py in <cell line: 0>()
#       6
#       7 # Plot histogram
# ----> 8 sns.histplot(sample, bins=15, kde=True,
#       9              color='steelblue', edgecolor='white',
#      10              kde_kws={'color': 'darkblue', 'linewidth': 2})
#
# /usr/local/lib/python3.12/dist-packages/seaborn/distributions.py in histplot(data, x, y, hue, weights, stat, bins, binwidth, binrange, discrete, cumulative, common_bins, common_norm, multiple, element, fill, shrink, kde, kde_kws, line_kws, thresh, pthresh, pmax, cbar, cbar_ax, cbar_kws, palette, hue_order, hue_norm, color, log_scale, legend, ax, **kwargs)
#    1414     if p.univariate:
#    1415
# -> 1416         p.plot_univariate_histogram(
#    1417             multiple=multiple,
#    1418             element=element,
#
# /usr/local/lib/python3.12/dist-packages/seaborn/distributions.py in plot_univariate_histogram(self, multiple, element, fill, common_norm, common_bins, shrink, kde, kde_kws, color, legend, line_kws, estimate_kws, **plot_kws)
#     445             kde_kws.setdefault("cut", 0)
#     446             kde_kws["cumulative"] = estimate_kws["cumulative"]
# --> 447             densities = self._compute_univariate_density(
#     448                 self.data_variable,
#     449                 common_norm,
#
# /usr/local/lib/python3.12/dist-packages/seaborn/distributions.py in _compute_univariate_density(self, data_variable, common_norm, common_grid, estimate_kws, warn_singular)
#     306
#     307         # Initialize the estimator object
# --> 308         estimator = KDE(**estimate_kws)
#     309
#     310         if set(self.variables) - {"x", "y"}:
#
# TypeError: KDE.__init__() got an unexpected keyword argument 'color'

# %%
# ==============================
# UJI NORMALITAS KOLMOGOROV-SMIRNOV
# ==============================

ks_stat, ks_pval = stats.kstest(sample, 'norm',
                                 args=(mean, std))
d_tabel = 1.36 / np.sqrt(len(sample))

print("=" * 45)
print("   UJI NORMALITAS KOLMOGOROV-SMIRNOV")
print("=" * 45)
print(f"D hitung        : {ks_stat:.4f}")
print(f"D tabel (α=0.05): {d_tabel:.4f}")
print(f"p-value         : {ks_pval:.4f}")
print("-" * 45)
if ks_pval >= 0.05:
    print("KEPUTUSAN: H0 DITERIMA")
    print("Data BERDISTRIBUSI NORMAL")
else:
    print("KEPUTUSAN: H0 DITOLAK")
    print("Data TIDAK berdistribusi normal")
print("=" * 45)

# %%
# ==============================
# ONE SAMPLE T-TEST
# ==============================

mu0    = 65.5
t_stat, t_pval = stats.ttest_1samp(sample, mu0)
t_tabel = stats.t.ppf(0.975, df=len(sample)-1)

print("=" * 45)
print("       ONE SAMPLE T-TEST")
print("=" * 45)
print(f"Rata-rata sampel (x̄) : {mean:.4f}")
print(f"Nilai hipotesis (μ₀)  : {mu0}")
print(f"Standar deviasi (s)   : {std:.4f}")
print(f"n                     : {len(sample)}")
print("-" * 45)
print(f"t hitung              : {t_stat:.4f}")
print(f"t tabel (α/2=0.025)   : {t_tabel:.4f}")
print(f"p-value               : {t_pval:.4f}")
print("-" * 45)
if t_pval >= 0.05:
    print("KEPUTUSAN: H0 DITERIMA")
    print("Tidak terdapat perbedaan signifikan")
else:
    print("KEPUTUSAN: H0 DITOLAK")
    print("Terdapat perbedaan yang signifikan")
print("=" * 45)
